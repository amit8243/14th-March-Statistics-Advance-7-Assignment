# %%
#Statistics Advance-7 Assignment
"""Q1. Write a Python function that takes in two arrays of data and calculates the F-value for a variance ratio
test. The function should return the F-value and the corresponding p-value for the test."""
Ans:def f_value(array1, array2):
    import scipy.stats as stats
    f_val, p_val = stats.f_oneway(array1, array2)
    return f_val, p_val

#Example:
array1 = [1,2,3,4]
array2 = [5,6,7,8]
f_value(array1, array2)
#Output: (9.0, 0.011724811003954654)

"""Q2. Given a significance level of 0.05 and the degrees of freedom for the numerator and denominator of an
F-distribution, write a Python function that returns the critical F-value for a two-tailed test."""
Ans: def critical_F_value(significance_level, numerator_df, denominator_df):
    from scipy.stats import f
    return f.ppf(1-significance_level/2, numerator_df, denominator_df)

#Example
critical_F_value(0.05, 5, 10)
#Output: 2.17558344732218

"""Q3. Write a Python program that generates random samples from two normal distributions with known
variances and uses an F-test to determine if the variances are equal. The program should output the F-
value, degrees of freedom, and p-value for the test."""
Ans: 
import numpy as np
from scipy.stats import f

# Generate random samples from two normal distributions with known variances
n1 = 100 # Sample size of first distribution 
n2 = 200 # Sample size of second distribution 
sigma1 = 5 # Variance of first distribution 
sigma2 = 10 # Variance of second distribution 
x1 = np.random.normal(0, sigma1, n1)
x2 = np.random.normal(0, sigma2, n2)


# Calculate F-test to determine if the variances are equal
F = (sigma1/sigma2)**2
df1 = n1 - 1 # Degrees of freedom for numerator 
df2 = n2 - 1 # Degrees of freedom for denominator 
p_value = 1 - f.cdf(F, df1, df2) # Calculate p-value

# Output F-value, degrees of freedom, and p-value for the test
print("F-value:", F)
print("Degrees of freedom (numerator):", df1)
print("Degrees of freedom (denominator):", df2)
print("p-value:", p_value)

"""Q4.The variances of two populations are known to be 10 and 15. A sample of 12 observations is taken from
each population. Conduct an F-test at the 5% significance level to determine if the variances are
significantly different."""

Ans: The critical value of F at the 5% significance level with 11 and 11 degrees of freedom is 3.89.

The test statistic is calculated as: 
F = (10/15) = 0.67

Since 0.67 < 3.89, we fail to reject the null hypothesis that the variances are not significantly 
different.

"""Q5. A manufacturer claims that the variance of the diameter of a certain product is 0.005. A sample of 25
products is taken, and the sample variance is found to be 0.006. Conduct an F-test at the 1% significance
level to determine if the claim is justified."""

Ans: H0: σ2 = 0.005
H1: σ2 ≠ 0.005

F-statistic = (0.006/0.005) = 1.2 

At the 1% significance level, the critical value of F is 3.84. 

Since the F-statistic (1.2) is less than the critical value (3.84), we fail to reject the null hypothesis
and conclude that the manufacturer's claim is justified.

"""Q6. Write a Python function that takes in the degrees of freedom for the numerator and denominator of an
F-distribution and calculates the mean and variance of the distribution. The function should return the
mean and variance as a tuple."""
Ans: 
def f_distribution(df_num, df_den):
    mean = df_num / (df_num - 2)
    variance = (2 * df_num**2 * df_den) / (df_num**2 * (df_den - 2)**2 * (df_den - 4))
    return (mean, variance)

# Test
print(f_distribution(3, 5)) # (1.5, 0.6)

"""Q7. A random sample of 10 measurements is taken from a normal population with unknown variance. The
sample variance is found to be 25. Another random sample of 15 measurements is taken from another
normal population with unknown variance, and the sample variance is found to be 20. Conduct an F-test
at the 10% significance level to determine if the variances are significantly different."""

Ans: The F-test statistic is calculated as follows: 
F = (25/10) / (20/15) = 1.25

At the 10% significance level, the critical value of F is 3.24. Since the calculated F-test statistic 
(1.25) is less than the critical value (3.24), we fail to reject the null hypothesis that the variances are
not significantly different.

Therefore, we conclude that the variances are not significantly different at the 10% significance level.

"""Q8. The following data represent the waiting times in minutes at two different restaurants on a Saturday
night: Restaurant A: 24, 25, 28, 23, 22, 20, 27; Restaurant B: 31, 33, 35, 30, 32, 36. Conduct an F-test at the 5%
significance level to determine if the variances are significantly different."""

Ans: F-test statistic = (Variance of Restaurant A) / (Variance of Restaurant B) = 8.14/13.33 = 0.61

Since the F-test statistic is less than the critical value of 3.84, we fail to reject the null hypothesis 
that the variances are equal. Therefore, we conclude that the variances are not significantly different at
the 5% significance level.

"""Q9. The following data represent the test scores of two groups of students: Group A: 80, 85, 90, 92, 87, 83;
Group B: 75, 78, 82, 79, 81, 84. Conduct an F-test at the 1% significance level to determine if the variances
are significantly different."""

Ans: F-test statistic = (Variance of Group A)/(Variance of Group B) = 8.9/4.2 = 2.12

At the 1% significance level, the critical value of F is 3.89. Since 2.12 < 3.89, we fail to reject the 
null hypothesis that the variances are equal.

Therefore, the variances are not significantly different.
